# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings

# %%
dataKR = pd.read_csv('KRmatch.csv', index_col=[0])
dataKR
# Out:
#       d_spell  f_spell champion       side           role  assists  \
# 0          14        4    Leona  Side.blue   Lane.utility        6
# 1          11        4     Udyr   Side.red    Lane.jungle        8
# 2          14        4   Xerath   Side.red   Lane.utility        2
# 3          14        4      Zoe   Side.red  Lane.mid_lane        8
# 4           4       12  Camille   Side.red  Lane.top_lane        8
# ...       ...      ...      ...        ...            ...      ...
# 5692       12        4      Vex   Side.red  Lane.mid_lane       18
# 5693        4        7   Ezreal   Side.red  Lane.bot_lane       10
# 5694       12        4    Jayce   Side.red  Lane.top_lane        3
# 5695        4       11  Nidalee   Side.red    Lane.jungle        6
# 5696       11        4   LeeSin  Side.blue    Lane.jungle       18
#
#       damage_objectives  damage_building  damage_turrets  deaths  ...  \
# 0                     0                0               0       6  ...
# ...

# %%
dataKR['champion'].value_counts()
# Out:
# Jhin       218
# LeeSin     214
# Graves     205
# Yone       151
# Caitlyn    143
#           ...
# Gnar         1
# Fizz         1
# Brand        1
# Ivern        1
# Rammus       1
# Name: champion, Length: 148, dtype: int64
